# %%
# Import the random module.
import random
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
from datetime import datetime

# %%
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e39a9ed129ac8f6e77b699dd51a10283

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),"Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | anadyr
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | charleston
# Processing Record 5 of Set 1 | meulaboh
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | mzimba
# Processing Record 8 of Set 1 | ondjiva
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | vrangel
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | changping
# Processing Record 16 of Set 1 | hami
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | olafsvik
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | kangaatsiaq
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | dingle
# Processing Record 24 of Set 1 | souillac
# Processing Record 25 of Set 1 | havelock
# Processing Record 26 of Set 1 | chaohu
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | pangnirtung
# Processing Record 29 of Set 1 | kavaratti
# Processing Record 30 of Set 1 | muros
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | bogorodskoye
# Processing Record 33 of Set 1 | malindi
# Processing Record 34 of Set 1 | ponta delgada
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | fortuna
# Processing Record 37 of Set 1 | vardo
# Processing Record 38 of Set 1 | san cristobal
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | port macquarie
# Processing Record 41 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 42 of Set 1 | yulara
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | chabahar
# Processing Record 46 of Set 1 | caravelas
# Processing Record 47 of Set 1 | vanimo
# Processing Record 48 of Set 1 | talcahuano
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | moose factory
# Processing Record 4 of Set 2 | cadereyta
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | kuvandyk
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | sao filipe
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | isangel
# Processing Record 13 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 2 | urucui
# Processing Record 15 of Set 2 | goksun
# Processing Record 16 of Set 2 | baghdad
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | foso
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | namibe
# Processing Record 22 of Set 2 | kaitangata
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | xinglongshan
# Processing Record 27 of Set 2 | kloulklubed
# Processing Record 28 of Set 2 | shingu
# Processing Record 29 of Set 2 | atar
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | bronnoysund
# Processing Record 32 of Set 2 | santa maria
# Processing Record 33 of Set 2 | roald
# Processing Record 34 of Set 2 | aguining
# Processing Record 35 of Set 2 | guerrero negro
# Processing Record 36 of Set 2 | morshansk
# Processing Record 37 of Set 2 | inirida
# Processing Record 38 of Set 2 | san jeronimo
# Processing Record 39 of Set 2 | baixa grande
# Processing Record 40 of Set 2 | porkhov
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | inhambane
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | amuntai
# Processing Record 45 of Set 2 | poronaysk
# Processing Record 46 of Set 2 | fallon
# Processing Record 47 of Set 2 | leningradskiy
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | sibut
# Processing Record 50 of Set 2 | hervey bay
# Processing Record 1 of Set 3 | hofn
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | teseney
# Processing Record 7 of Set 3 | alangilanan
# Processing Record 8 of Set 3 | tuatapere
# Processing Record 9 of Set 3 | moussoro
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | fairbanks
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | ouro preto do oeste
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | humberto de campos
# Processing Record 17 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 3 | binzhou
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | galesong
# Processing Record 21 of Set 3 | narsaq
# Processing Record 22 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 3 | dunedin
# Processing Record 26 of Set 3 | port keats
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | sola
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | vestmannaeyjar
# Processing Record 31 of Set 3 | snezhnogorsk
# Processing Record 32 of Set 3 | hambantota
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | ahuimanu
# Processing Record 35 of Set 3 | puerto palomas
# Processing Record 36 of Set 3 | mhlume
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | payerne
# Processing Record 40 of Set 3 | kamaishi
# Processing Record 41 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 3 | rantepao
# Processing Record 43 of Set 3 | port hardy
# Processing Record 44 of Set 3 | batagay-alyta
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | yialos
# City not found. Skipping...
# Processing Record 48 of Set 3 | goshogawara
# Processing Record 49 of Set 3 | raga
# Processing Record 50 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 4 | shanghai
# Processing Record 2 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 4 | scarborough
# Processing Record 4 of Set 4 | nhulunbuy
# Processing Record 5 of Set 4 | juruti
# Processing Record 6 of Set 4 | suntar
# Processing Record 7 of Set 4 | ozd
# Processing Record 8 of Set 4 | kangalassy
# Processing Record 9 of Set 4 | ponta do sol
# Processing Record 10 of Set 4 | tamandare
# Processing Record 11 of Set 4 | nemuro
# Processing Record 12 of Set 4 | tivaouane
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | whitehorse
# Processing Record 15 of Set 4 | cap-aux-meules
# Processing Record 16 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 4 | tripoli
# Processing Record 18 of Set 4 | kovernino
# Processing Record 19 of Set 4 | zakopane
# Processing Record 20 of Set 4 | jamestown
# Processing Record 21 of Set 4 | portland
# Processing Record 22 of Set 4 | mildura
# Processing Record 23 of Set 4 | la vergne
# Processing Record 24 of Set 4 | khatanga
# Processing Record 25 of Set 4 | belen
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | kruisfontein
# Processing Record 28 of Set 4 | harper
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | tessalit
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | taldan
# Processing Record 33 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | payo
# Processing Record 36 of Set 4 | duliby
# Processing Record 37 of Set 4 | vila velha
# Processing Record 38 of Set 4 | tiksi
# Processing Record 39 of Set 4 | summerville
# Processing Record 40 of Set 4 | mount isa
# Processing Record 41 of Set 4 | khorixas
# Processing Record 42 of Set 4 | airai
# Processing Record 43 of Set 4 | san quintin
# Processing Record 44 of Set 4 | lasa
# Processing Record 45 of Set 4 | bluefield
# Processing Record 46 of Set 4 | alofi
# Processing Record 47 of Set 4 | sorland
# Processing Record 48 of Set 4 | matelica
# Processing Record 49 of Set 4 | katakwi
# Processing Record 50 of Set 4 | isiro
# Processing Record 1 of Set 5 | charagua
# Processing Record 2 of Set 5 | sodertalje
# City not found. Skipping...
# Processing Record 3 of Set 5 | aklavik
# Processing Record 4 of Set 5 | chimoio
# Processing Record 5 of Set 5 | saint anthony
# Processing Record 6 of Set 5 | babai
# Processing Record 7 of Set 5 | mittagong
# Processing Record 8 of Set 5 | santa cruz
# Processing Record 9 of Set 5 | bubaque
# Processing Record 10 of Set 5 | grindavik
# Processing Record 11 of Set 5 | pacific grove
# Processing Record 12 of Set 5 | gunjur
# Processing Record 13 of Set 5 | lufilufi
# Processing Record 14 of Set 5 | khash
# Processing Record 15 of Set 5 | sterling
# Processing Record 16 of Set 5 | severnyy
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | sao geraldo do araguaia
# Processing Record 19 of Set 5 | clarksville
# Processing Record 20 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 5 | esperance
# Processing Record 22 of Set 5 | jijiga
# Processing Record 23 of Set 5 | yeehaw junction
# City not found. Skipping...
# Processing Record 24 of Set 5 | sitka
# Processing Record 25 of Set 5 | ko samui
# Processing Record 26 of Set 5 | kitgum
# Processing Record 27 of Set 5 | jesus de otoro
# Processing Record 28 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 5 | trairi
# Processing Record 30 of Set 5 | kushiro
# Processing Record 31 of Set 5 | mehamn
# Processing Record 32 of Set 5 | benalla
# Processing Record 33 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 5 | dunda
# Processing Record 36 of Set 5 | malumfashi
# Processing Record 37 of Set 5 | kalispell
# Processing Record 38 of Set 5 | yar-sale
# Processing Record 39 of Set 5 | susehri
# Processing Record 40 of Set 5 | bac lieu
# Processing Record 41 of Set 5 | richards bay
# Processing Record 42 of Set 5 | vostok
# Processing Record 43 of Set 5 | iquitos
# Processing Record 44 of Set 5 | barabai
# Processing Record 45 of Set 5 | beringovskiy
# Processing Record 46 of Set 5 | moyale
# Processing Record 47 of Set 5 | cherskiy
# Processing Record 48 of Set 5 | primorsk
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | haines junction
# Processing Record 1 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 6 | touros
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | ahipara
# Processing Record 5 of Set 6 | bela
# Processing Record 6 of Set 6 | karpathos
# Processing Record 7 of Set 6 | khandyga
# Processing Record 8 of Set 6 | shetpe
# Processing Record 9 of Set 6 | tupik
# Processing Record 10 of Set 6 | mataram
# Processing Record 11 of Set 6 | batagay
# Processing Record 12 of Set 6 | sangar
# Processing Record 13 of Set 6 | prachuap khiri khan
# Processing Record 14 of Set 6 | acapulco
# Processing Record 15 of Set 6 | baykit
# Processing Record 16 of Set 6 | latina
# Processing Record 17 of Set 6 | salisbury
# Processing Record 18 of Set 6 | karratha
# Processing Record 19 of Set 6 | kisangani
# Processing Record 20 of Set 6 | shache
# Processing Record 21 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 6 | comodoro rivadavia
# Processing Record 23 of Set 6 | hamilton
# Processing Record 24 of Set 6 | saldanha
# Processing Record 25 of Set 6 | lazaro cardenas
# Processing Record 26 of Set 6 | durango
# Processing Record 27 of Set 6 | copiapo
# Processing Record 28 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 29 of Set 6 | ratnagiri
# Processing Record 30 of Set 6 | halifax
# Processing Record 31 of Set 6 | ormara
# Processing Record 32 of Set 6 | sioux falls
# Processing Record 33 of Set 6 | ntcheu
# Processing Record 34 of Set 6 | presidente medici
# Processing Record 35 of Set 6 | warrington
# Processing Record 36 of Set 6 | ippy
# Processing Record 37 of Set 6 | poso
# Processing Record 38 of Set 6 | singapore
# Processing Record 39 of Set 6 | galle
# Processing Record 40 of Set 6 | ixtapa
# Processing Record 41 of Set 6 | cabra
# Processing Record 42 of Set 6 | ambilobe
# Processing Record 43 of Set 6 | mezen
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | upata
# Processing Record 46 of Set 6 | ancud
# Processing Record 47 of Set 6 | ust-ishim
# Processing Record 48 of Set 6 | swan hill
# Processing Record 49 of Set 6 | mahon
# Processing Record 50 of Set 6 | linxia
# Processing Record 1 of Set 7 | bethel
# Processing Record 2 of Set 7 | chapleau
# Processing Record 3 of Set 7 | ulaangom
# Processing Record 4 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 7 | bathsheba
# Processing Record 6 of Set 7 | yabrud
# Processing Record 7 of Set 7 | sovetskaya
# Processing Record 8 of Set 7 | upernavik
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | inta
# Processing Record 11 of Set 7 | walvis bay
# Processing Record 12 of Set 7 | kodiak
# Processing Record 13 of Set 7 | grand gaube
# Processing Record 14 of Set 7 | saint-augustin
# Processing Record 15 of Set 7 | bandarbeyla
# Processing Record 16 of Set 7 | plettenberg bay
# Processing Record 17 of Set 7 | geraldton
# Processing Record 18 of Set 7 | fare
# Processing Record 19 of Set 7 | saint stephen
# Processing Record 20 of Set 7 | balkanabat
# Processing Record 21 of Set 7 | necochea
# Processing Record 22 of Set 7 | helong
# Processing Record 23 of Set 7 | butaritari
# Processing Record 24 of Set 7 | kasra
# City not found. Skipping...
# Processing Record 25 of Set 7 | pevek
# Processing Record 26 of Set 7 | kita
# Processing Record 27 of Set 7 | quimper
# Processing Record 28 of Set 7 | xining
# Processing Record 29 of Set 7 | flinders
# Processing Record 30 of Set 7 | magadan
# Processing Record 31 of Set 7 | diapaga
# Processing Record 32 of Set 7 | kapuskasing
# Processing Record 33 of Set 7 | boralday
# Processing Record 34 of Set 7 | awjilah
# Processing Record 35 of Set 7 | inuvik
# Processing Record 36 of Set 7 | novikovo
# Processing Record 37 of Set 7 | dinguiraye
# Processing Record 38 of Set 7 | nyurba
# Processing Record 39 of Set 7 | aripuana
# Processing Record 40 of Set 7 | carutapera
# Processing Record 41 of Set 7 | rocha
# Processing Record 42 of Set 7 | salekhard
# Processing Record 43 of Set 7 | sisimiut
# Processing Record 44 of Set 7 | foz
# Processing Record 45 of Set 7 | mackay
# Processing Record 46 of Set 7 | santa isabel do rio negro
# Processing Record 47 of Set 7 | buraydah
# Processing Record 48 of Set 7 | champerico
# Processing Record 49 of Set 7 | forrest city
# Processing Record 50 of Set 7 | malakal
# Processing Record 1 of Set 8 | adrar
# Processing Record 2 of Set 8 | agirish
# Processing Record 3 of Set 8 | alvik
# Processing Record 4 of Set 8 | pasni
# Processing Record 5 of Set 8 | eagle
# Processing Record 6 of Set 8 | bambanglipuro
# Processing Record 7 of Set 8 | kassala
# Processing Record 8 of Set 8 | fauske
# Processing Record 9 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 8 | north branch
# Processing Record 11 of Set 8 | awbari
# Processing Record 12 of Set 8 | miraflores
# Processing Record 13 of Set 8 | antalaha
# Processing Record 14 of Set 8 | jalu
# Processing Record 15 of Set 8 | port said
# Processing Record 16 of Set 8 | jinka
# Processing Record 17 of Set 8 | atambua
# Processing Record 18 of Set 8 | safaga
# Processing Record 19 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 8 | chokurdakh
# Processing Record 21 of Set 8 | nara
# Processing Record 22 of Set 8 | kapoeta
# Processing Record 23 of Set 8 | general pico
# Processing Record 24 of Set 8 | maceio
# Processing Record 25 of Set 8 | jati
# Processing Record 26 of Set 8 | namatanai
# Processing Record 27 of Set 8 | buin
# Processing Record 28 of Set 8 | codrington
# Processing Record 29 of Set 8 | tarko-sale
# Processing Record 30 of Set 8 | liverpool
# Processing Record 31 of Set 8 | shenjiamen
# Processing Record 32 of Set 8 | bayonet point
# Processing Record 33 of Set 8 | camacupa
# Processing Record 34 of Set 8 | henties bay
# Processing Record 35 of Set 8 | balakhninskiy
# Processing Record 36 of Set 8 | yunyang
# Processing Record 37 of Set 8 | opuwo
# Processing Record 38 of Set 8 | kununurra
# Processing Record 39 of Set 8 | ruma
# Processing Record 40 of Set 8 | verkhnyaya inta
# Processing Record 41 of Set 8 | kijang
# Processing Record 42 of Set 8 | buala
# Processing Record 43 of Set 8 | burica
# City not found. Skipping...
# Processing Record 44 of Set 8 | ballina
# Processing Record 45 of Set 8 | mani
# Processing Record 46 of Set 8 | broome
# Processing Record 47 of Set 8 | bealanana
# Processing Record 48 of Set 8 | los llanos de aridane
# Processing Record 49 of Set 8 | thaba nchu
# Processing Record 50 of Set 8 | northam
# Processing Record 1 of Set 9 | novo aripuana
# Processing Record 2 of Set 9 | buckeye
# Processing Record 3 of Set 9 | onega
# Processing Record 4 of Set 9 | ostrovnoy
# Processing Record 5 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 9 | goderich
# Processing Record 7 of Set 9 | mayo
# Processing Record 8 of Set 9 | margate
# Processing Record 9 of Set 9 | balykshi
# Processing Record 10 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 9 | paamiut
# Processing Record 12 of Set 9 | aksha
# Processing Record 13 of Set 9 | lagoa
# Processing Record 14 of Set 9 | komsomolskiy
# Processing Record 15 of Set 9 | keuruu
# Processing Record 16 of Set 9 | jacksonville beach
# Processing Record 17 of Set 9 | penzance
# Processing Record 18 of Set 9 | shakawe
# Processing Record 19 of Set 9 | san rafael
# Processing Record 20 of Set 9 | kargopol
# Processing Record 21 of Set 9 | teneguiban
# City not found. Skipping...
# Processing Record 22 of Set 9 | rio grande
# Processing Record 23 of Set 9 | ekibastuz
# Processing Record 24 of Set 9 | kirksville
# Processing Record 25 of Set 9 | olinda
# Processing Record 26 of Set 9 | ajtos
# Processing Record 27 of Set 9 | pozo colorado
# Processing Record 28 of Set 9 | guane
# Processing Record 29 of Set 9 | kavieng
# Processing Record 30 of Set 9 | murgab
# Processing Record 31 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 9 | saint george
# Processing Record 33 of Set 9 | rockport
# Processing Record 34 of Set 9 | egvekinot
# Processing Record 35 of Set 9 | takoradi
# Processing Record 36 of Set 9 | yelan
# Processing Record 37 of Set 9 | prince george
# Processing Record 38 of Set 9 | ngerengere
# Processing Record 39 of Set 9 | jizan
# Processing Record 40 of Set 9 | chapada dos guimaraes
# Processing Record 41 of Set 9 | wundanyi
# Processing Record 42 of Set 9 | wahiawa
# Processing Record 43 of Set 9 | rabo de peixe
# Processing Record 44 of Set 9 | tomatlan
# Processing Record 45 of Set 9 | mountain home
# Processing Record 46 of Set 9 | soloneshnoye
# Processing Record 47 of Set 9 | hoquiam
# Processing Record 48 of Set 9 | junction city
# Processing Record 49 of Set 9 | salinas
# Processing Record 50 of Set 9 | gold coast
# Processing Record 1 of Set 10 | benghazi
# Processing Record 2 of Set 10 | paracatu
# Processing Record 3 of Set 10 | karpuninskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | tura
# Processing Record 5 of Set 10 | omboue
# Processing Record 6 of Set 10 | tynda
# Processing Record 7 of Set 10 | lompoc
# Processing Record 8 of Set 10 | ilulissat
# Processing Record 9 of Set 10 | saint-francois
# Processing Record 10 of Set 10 | katobu
# Processing Record 11 of Set 10 | virginia beach
# Processing Record 12 of Set 10 | mmathubudukwane
# Processing Record 13 of Set 10 | kimberley
# Processing Record 14 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 10 | zhigansk
# Processing Record 16 of Set 10 | ulladulla
# Processing Record 17 of Set 10 | progreso
# Processing Record 18 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 19 of Set 10 | winslow
# Processing Record 20 of Set 10 | bulgan
# Processing Record 21 of Set 10 | chapais
# Processing Record 22 of Set 10 | mitu
# Processing Record 23 of Set 10 | tombouctou
# Processing Record 24 of Set 10 | skagen
# Processing Record 25 of Set 10 | republic
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | nizwa
# Processing Record 28 of Set 10 | chadiza
# Processing Record 29 of Set 10 | veinticinco de mayo
# Processing Record 30 of Set 10 | saucillo
# Processing Record 31 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 32 of Set 10 | lima
# Processing Record 33 of Set 10 | taltal
# Processing Record 34 of Set 10 | calvinia
# Processing Record 35 of Set 10 | andros town
# Processing Record 36 of Set 10 | eston
# Processing Record 37 of Set 10 | makakilo city
# Processing Record 38 of Set 10 | tlacotepec
# Processing Record 39 of Set 10 | east liverpool
# Processing Record 40 of Set 10 | tezu
# Processing Record 41 of Set 10 | aswan
# Processing Record 42 of Set 10 | hongjiang
# Processing Record 43 of Set 10 | svetlogorsk
# Processing Record 44 of Set 10 | linqiong
# Processing Record 45 of Set 10 | mitsamiouli
# Processing Record 46 of Set 10 | astoria
# Processing Record 47 of Set 10 | chazuta
# Processing Record 48 of Set 10 | litovko
# Processing Record 49 of Set 10 | korcula
# Processing Record 50 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 1 of Set 11 | brae
# Processing Record 2 of Set 11 | puerto colombia
# Processing Record 3 of Set 11 | kendari
# Processing Record 4 of Set 11 | gornopravdinsk
# Processing Record 5 of Set 11 | wanning
# Processing Record 6 of Set 11 | paracuru
# Processing Record 7 of Set 11 | obluche
# City not found. Skipping...
# Processing Record 8 of Set 11 | iqaluit
# Processing Record 9 of Set 11 | carballo
# Processing Record 10 of Set 11 | salalah
# Processing Record 11 of Set 11 | pemberton
# Processing Record 12 of Set 11 | katangli
# Processing Record 13 of Set 11 | bakel
# Processing Record 14 of Set 11 | salinopolis
# Processing Record 15 of Set 11 | vilhena
# Processing Record 16 of Set 11 | pekalongan
# Processing Record 17 of Set 11 | sabha
# Processing Record 18 of Set 11 | vallenar
# Processing Record 19 of Set 11 | huarmey
# Processing Record 20 of Set 11 | lady frere
# Processing Record 21 of Set 11 | mareeba
# Processing Record 22 of Set 11 | abu dhabi
# Processing Record 23 of Set 11 | alta floresta
# Processing Record 24 of Set 11 | bowen
# Processing Record 25 of Set 11 | labuhan
# Processing Record 26 of Set 11 | kalininsk
# Processing Record 27 of Set 11 | te anau
# Processing Record 28 of Set 11 | nykoping
# Processing Record 29 of Set 11 | solnechnyy
# Processing Record 30 of Set 11 | ampanihy
# Processing Record 31 of Set 11 | tromso
# Processing Record 32 of Set 11 | araua
# Processing Record 33 of Set 11 | codajas
# Processing Record 34 of Set 11 | koundara
# Processing Record 35 of Set 11 | clifton springs
# Processing Record 36 of Set 11 | qaqortoq
# Processing Record 37 of Set 11 | pingzhuang
# Processing Record 38 of Set 11 | banjar
# Processing Record 39 of Set 11 | lebyazhye
# Processing Record 40 of Set 11 | zhezkazgan
# Processing Record 41 of Set 11 | palampur
# Processing Record 42 of Set 11 | igarka
# Processing Record 43 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 11 | taksimo
# Processing Record 45 of Set 11 | nome
# Processing Record 46 of Set 11 | vangaindrano
# Processing Record 47 of Set 11 | santa isabel
# Processing Record 48 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 11 | mount gambier
# Processing Record 50 of Set 11 | chumikan
# Processing Record 1 of Set 12 | eureka
# Processing Record 2 of Set 12 | sambava
# Processing Record 3 of Set 12 | srednekolymsk
# Processing Record 4 of Set 12 | changzhou
# Processing Record 5 of Set 12 | capitan bado
# Processing Record 6 of Set 12 | sayansk
# Processing Record 7 of Set 12 | arlit
# Processing Record 8 of Set 12 | goundi
# Processing Record 9 of Set 12 | namanga
# Processing Record 10 of Set 12 | las choapas
# Processing Record 11 of Set 12 | hualmay
# Processing Record 12 of Set 12 | dongying
# Processing Record 13 of Set 12 | berlevag
# Processing Record 14 of Set 12 | maturin
# Processing Record 15 of Set 12 | oktyabrskoye
# Processing Record 16 of Set 12 | huancabamba
# Processing Record 17 of Set 12 | iralaya
# Processing Record 18 of Set 12 | cotonou
# Processing Record 19 of Set 12 | kathmandu
# Processing Record 20 of Set 12 | brasilia de minas
# Processing Record 21 of Set 12 | doha
# Processing Record 22 of Set 12 | bonthe
# Processing Record 23 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 12 | sakete
# Processing Record 25 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 12 | kinlochleven
# Processing Record 27 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 28 of Set 12 | nabire
# Processing Record 29 of Set 12 | clearwater
# Processing Record 30 of Set 12 | zlobin
# Processing Record 31 of Set 12 | ambovombe
# Processing Record 32 of Set 12 | itoman
# Processing Record 33 of Set 12 | chateaubelair
# Processing Record 34 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 12 | mogadishu
# Processing Record 36 of Set 12 | kaspiysk
# Processing Record 37 of Set 12 | bahadurganj
# Processing Record 38 of Set 12 | kropotkin
# Processing Record 39 of Set 12 | new haven
# Processing Record 40 of Set 12 | golkoy
# Processing Record 41 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 12 | moron
# Processing Record 43 of Set 12 | sinnamary
# Processing Record 44 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 12 | medina del campo
# Processing Record 46 of Set 12 | mednogorsk
# Processing Record 47 of Set 12 | nanortalik
# Processing Record 48 of Set 12 | gizo
# Processing Record 49 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 50 of Set 12 | malatya
# Processing Record 1 of Set 13 | soyo
# Processing Record 2 of Set 13 | luang prabang
# Processing Record 3 of Set 13 | clyde river
# Processing Record 4 of Set 13 | cumbum
# Processing Record 5 of Set 13 | vizimyary
# City not found. Skipping...
# Processing Record 6 of Set 13 | chalmette
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | katsuura
# Processing Record 9 of Set 13 | liberal
# Processing Record 10 of Set 13 | camacha
# Processing Record 11 of Set 13 | san angelo
# Processing Record 12 of Set 13 | wattegama
# Processing Record 13 of Set 13 | huilong
# Processing Record 14 of Set 13 | keta
# Processing Record 15 of Set 13 | krasnoarmeyskoye
# Processing Record 16 of Set 13 | jacareacanga
# Processing Record 17 of Set 13 | presov
# Processing Record 18 of Set 13 | waingapu
# Processing Record 19 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 13 | vao
# Processing Record 21 of Set 13 | maragogipe
# Processing Record 22 of Set 13 | pangkalanbuun
# Processing Record 23 of Set 13 | rawson
# Processing Record 24 of Set 13 | chepareria
# Processing Record 25 of Set 13 | praia
# Processing Record 26 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 13 | singaraja
# Processing Record 28 of Set 13 | toamasina
# Processing Record 29 of Set 13 | havoysund
# Processing Record 30 of Set 13 | kambove
# Processing Record 31 of Set 13 | santa fe
# Processing Record 32 of Set 13 | pestravka
# Processing Record 33 of Set 13 | shintomi
# Processing Record 34 of Set 13 | sao sepe
# Processing Record 35 of Set 13 | bosobolo
# Processing Record 36 of Set 13 | lata
# Processing Record 37 of Set 13 | zhuhai
# Processing Record 38 of Set 13 | dong hoi
# Processing Record 39 of Set 13 | semey
# Processing Record 40 of Set 13 | noumea
# Processing Record 41 of Set 13 | luderitz
# Processing Record 42 of Set 13 | hastings
# Processing Record 43 of Set 13 | fez
# Processing Record 44 of Set 13 | kachiry
# Processing Record 45 of Set 13 | tanjong karang
# City not found. Skipping...
# Processing Record 46 of Set 13 | boddam
# Processing Record 47 of Set 13 | desaguadero
# Processing Record 48 of Set 13 | rumoi
# Processing Record 49 of Set 13 | payson
# Processing Record 50 of Set 13 | barra da estiva
# Processing Record 1 of Set 14 | cockburn town
# Processing Record 2 of Set 14 | jieshi
# Processing Record 3 of Set 14 | constitucion
# Processing Record 4 of Set 14 | ayorou
# Processing Record 5 of Set 14 | chekhov
# Processing Record 6 of Set 14 | mahibadhoo
# Processing Record 7 of Set 14 | kingsville
# Processing Record 8 of Set 14 | kaeo
# Processing Record 9 of Set 14 | innisfail
# Processing Record 10 of Set 14 | tambura
# Processing Record 11 of Set 14 | homer
# Processing Record 12 of Set 14 | parras
# City not found. Skipping...
# Processing Record 13 of Set 14 | westport
# Processing Record 14 of Set 14 | bay roberts
# Processing Record 15 of Set 14 | lingao
# Processing Record 16 of Set 14 | tautira
# Processing Record 17 of Set 14 | maragogi
# Processing Record 18 of Set 14 | poya
# Processing Record 19 of Set 14 | karasburg
# Processing Record 20 of Set 14 | cascais
# Processing Record 21 of Set 14 | valentin gomez farias
# Processing Record 22 of Set 14 | xuddur
# Processing Record 23 of Set 14 | esil
# Processing Record 24 of Set 14 | jaciara
# Processing Record 25 of Set 14 | artesia
# Processing Record 26 of Set 14 | batemans bay
# Processing Record 27 of Set 14 | bria
# Processing Record 28 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 14 | baoning
# Processing Record 30 of Set 14 | inongo
# Processing Record 31 of Set 14 | paita
# Processing Record 32 of Set 14 | riyadh
# Processing Record 33 of Set 14 | cayenne
# Processing Record 34 of Set 14 | nefteyugansk
# Processing Record 35 of Set 14 | angoche
# Processing Record 36 of Set 14 | avera
# Processing Record 37 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 14 | black river
# Processing Record 39 of Set 14 | praia da vitoria
# Processing Record 40 of Set 14 | sibolga
# Processing Record 41 of Set 14 | marsh harbour
# Processing Record 42 of Set 14 | oranjemund
# Processing Record 43 of Set 14 | cochrane
# Processing Record 44 of Set 14 | warri
# Processing Record 45 of Set 14 | sabang
# Processing Record 46 of Set 14 | birjand
# Processing Record 47 of Set 14 | chapaevsk
# Processing Record 48 of Set 14 | ishigaki
# Processing Record 49 of Set 14 | kieta
# Processing Record 50 of Set 14 | lorengau
# Processing Record 1 of Set 15 | new ross
# Processing Record 2 of Set 15 | sur
# Processing Record 3 of Set 15 | sept-iles
# Processing Record 4 of Set 15 | isla mujeres
# Processing Record 5 of Set 15 | gorontalo
# Processing Record 6 of Set 15 | povenets
# Processing Record 7 of Set 15 | antofagasta
# Processing Record 8 of Set 15 | aquiraz
# Processing Record 9 of Set 15 | ngozi
# Processing Record 10 of Set 15 | socorro
# Processing Record 11 of Set 15 | yumen
# Processing Record 12 of Set 15 | puerto escondido
# Processing Record 13 of Set 15 | juba
# Processing Record 14 of Set 15 | elko
# Processing Record 15 of Set 15 | petapa
# Processing Record 16 of Set 15 | zapolyarnyy
# Processing Record 17 of Set 15 | korla
# Processing Record 18 of Set 15 | holetown
# Processing Record 19 of Set 15 | sao vicente
# Processing Record 20 of Set 15 | salina cruz
# Processing Record 21 of Set 15 | kantunilkin
# Processing Record 22 of Set 15 | nioro
# Processing Record 23 of Set 15 | pahrump
# Processing Record 24 of Set 15 | negombo
# Processing Record 25 of Set 15 | zwedru
# Processing Record 26 of Set 15 | madras
# Processing Record 27 of Set 15 | bilibino
# Processing Record 28 of Set 15 | nuuk
# Processing Record 29 of Set 15 | mayumba
# Processing Record 30 of Set 15 | paiho
# City not found. Skipping...
# Processing Record 31 of Set 15 | port shepstone
# Processing Record 32 of Set 15 | kargil
# Processing Record 33 of Set 15 | ovsyanka
# Processing Record 34 of Set 15 | vargem grande
# Processing Record 35 of Set 15 | palmares do sul
# Processing Record 36 of Set 15 | gazojak
# Processing Record 37 of Set 15 | greece
# Processing Record 38 of Set 15 | laguna
# Processing Record 39 of Set 15 | toribio
# Processing Record 40 of Set 15 | bahir dar
# Processing Record 41 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 15 | zhangye
# Processing Record 43 of Set 15 | pavlodar
# Processing Record 44 of Set 15 | warrnambool
# Processing Record 45 of Set 15 | shelabolikha
# Processing Record 46 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 15 | san patricio
# Processing Record 48 of Set 15 | imaculada
# Processing Record 49 of Set 15 | college
# Processing Record 50 of Set 15 | zuwarah
# Processing Record 1 of Set 16 | north bend
# Processing Record 2 of Set 16 | alugan
# Processing Record 3 of Set 16 | sioux lookout
# Processing Record 4 of Set 16 | metro
# Processing Record 5 of Set 16 | canyon
# Processing Record 6 of Set 16 | buqayq
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Anadyr      RU  64.7500  177.4833     -4.00        77          20
# 1  Yellowknife      CA  62.4560 -114.3525      9.00        61          20
# 2   Charleston      US  32.7766  -79.9309     84.20        73           1
# 3     Meulaboh      ID   4.1363   96.1285     76.23        84         100
# 4      Rikitea      PF -23.1203 -134.9692     79.23        71           1
# 5       Mzimba      MW -11.9000   33.6000     61.95        98         100
# 6      Ondjiva      AO -17.0667   15.7333     69.04        77          56
# 7  Port Alfred      ZA -33.5906   26.8910     69.12        88         100
# 8      Ushuaia      AR -54.8000  -68.3000     51.80        54          40
# 9      Mataura      NZ -46.1927  168.8643     57.00        83         100
#
#    Wind Speed Current Description
# 0       13.42          few clouds
# 1        9.22          few clouds
# 2       14.97           clear sky
# 3        1.39     overcast clouds
# 4       18.88           clear sky
# 5        0.89          light rain
# 6        3.29       broken clouds
# 7       14.20     overcast clouds
# 8        8.05    scattered clouds
# 9        1.99          light rain
